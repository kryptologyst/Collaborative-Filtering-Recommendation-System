# %% [markdown]
# # Collaborative Filtering Recommendation System
#
# This notebook demonstrates how to use the collaborative filtering recommendation system with different algorithms.

# %%
import sys
import os
sys.path.append('src')

import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

from models.collaborative_filtering import UserBasedCF, ItemBasedCF, MatrixFactorization, SVDModel
from data.dataset import MovieLensDataset
from evaluation.metrics import evaluate_model, compare_models

# Set style
plt.style.use('seaborn-v0_8')
sns.set_palette("husl")
